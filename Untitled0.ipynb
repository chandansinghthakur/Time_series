# %% [markdown]
# <a href="https://colab.research.google.com/github/chandansinghthakur/Time_series/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'/content/Recruiter and Account manager list.xlsx')

# %%
df.head()
# Out:
#   Employee code   Recruiter Name  Account Manager  Repoting Manager Division  \
# 0       ET-3823  Pyare Lal Singh  Abhinish Swaroop       Vivek Vats      HCL
# 1       ET-3826     Ankur Sharma  Abhinish Swaroop       Vivek Vats      HCL
# 2       ET-3831   Anupam Awasthi  Abhinish Swaroop       Vivek Vats      HCL
# 3       ET-3881      Swati Singh  Abhinish Swaroop       Vivek Vats      HCL
# 4       ET-3882       Aman Gupta  Abhinish Swaroop       Vivek Vats      HCL
#
#                   Designation                Email id  Ext Number  \
# 0  Senior Technical Recruiter      pyare.l@emonics.com       5421
# 1  Senior Technical Recruiter      ankur.s@emonics.com       5423
# 2                   Team Lead     anupam.a@emonics.com       5426
# 3         Technical Recruiter  swati.singh@emonics.com       5174
# 4  Senior Technical Recruiter   aman.gupta@emonics.com       5220
#
#     Phone Numbers Date of Joining
# 0  (732) 629-9372      2022-08-08
# 1  (201) 484-0174      2022-08-08
# ...

# %%
df.sort_values(by=['Repoting Manager']).head()
# Out:
#     Employee code  Recruiter Name  Account Manager  Repoting Manager  \
# 86        ET-3469       Ayush Raj  Md Touqir Ansari  Ankit Kumar Jat
# 127       ET-3679        Mayank k       Pintu Singh  Ankit Kumar Jat
# 128       ET-3681  Anshdeep Singh       Pintu Singh  Ankit Kumar Jat
# 129       ET-3693     Abhay Singh       Pintu Singh  Ankit Kumar Jat
# 130       ET-3695     Mohd. Uvesh       Pintu Singh  Ankit Kumar Jat
#
#          Division                 Designation               Email id   \
# 86   TCS Fulltime         Technical Recruiter   ayush.raj@emonics.com
# 127  TCS Fulltime         Technical Recruiter     mayank2@emonics.com
# 128  TCS Fulltime         Technical Recruiter  anshdeep.s@emonics.com
# 129  TCS Fulltime  Senior Technical Recruiter     abhay.s@emonics.com
# 130  TCS Fulltime         Technical Recruiter       uvesh@emonics.com
#
#     Ext Number   Phone Numbers Date of Joining
# 86        5256  (551) 465-6094      2022-06-08
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.count()
# Out:
# Employee code       242
# Recruiter Name      244
# Account Manager     244
# Repoting Manager    244
# Division            244
# Designation         244
# Email id            244
# Ext Number          244
# Phone Numbers       244
# Date of Joining     244
# dtype: int64

# %%
df.describe().T
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                   count unique                  top freq      first       last
# Employee code       242    242              ET-3823    1        NaT        NaT
# Recruiter Name      244    243       Abhishek Kumar    2        NaT        NaT
# Account Manager     244     50      Papul Chaudhary   16        NaT        NaT
# Repoting Manager    244     14           Ashu Dubey   46        NaT        NaT
# Division            244     11         TCS Fulltime   47        NaT        NaT
# Designation         244     30  Technical Recruiter  100        NaT        NaT
# ...

# %%
ph = df[['Phone Numbers']]

# %%
ph.head()
# Out:
#     Phone Numbers
# 0  (732) 629-9372
# 1  (201) 484-0174
# 2  (201) 621-5669
# 3  (551) 310-0428
# 4  (201) 474-8453

# %%
ph = df['Phone Numbers'].str.replace("-","")

# %%
# ph1 = ph.str.replace("(","")
# ph2 = ph1.str.replace(")","")
# ph3 = ph2.str.replace(" ","")
ph3
# Out:
# 0      7326299372
# 1      2014840174
# 2      2016215669
# 3      5513100428
# 4      2014748453
#           ...
# 239    5514656102
# 240    5513101706
# 241    2013402224
# 242    5514656063
# 243    5512613203
# Name: Phone Numbers, Length: 244, dtype: object

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
